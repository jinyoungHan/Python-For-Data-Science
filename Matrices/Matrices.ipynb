# %%
A = [[[27,26,25,24,23,22,21],[17,16,15,14,13,12,11],[7,6,5,4,3,2,1]],
     [[37,36,35,34,33,32,31],[47,46,45,44,43,42,41],[57,56,55,54,53,52,51]]]

# %%
A
# Out:
# [[[27, 26, 25, 24, 23, 22, 21],
#   [17, 16, 15, 14, 13, 12, 11],
#   [7, 6, 5, 4, 3, 2, 1]],
#  [[37, 36, 35, 34, 33, 32, 31],
#   [47, 46, 45, 44, 43, 42, 41],
#   [57, 56, 55, 54, 53, 52, 51]]]

# %%
A[1]
# Out:
# [[37, 36, 35, 34, 33, 32, 31],
#  [47, 46, 45, 44, 43, 42, 41],
#  [57, 56, 55, 54, 53, 52, 51]]

# %%
A[0]
# Out:
# [[27, 26, 25, 24, 23, 22, 21],
#  [17, 16, 15, 14, 13, 12, 11],
#  [7, 6, 5, 4, 3, 2, 1]]

# %%
A[0][1]
# Out:
# [17, 16, 15, 14, 13, 12, 11]

# %%
B = [[1,2,3,4,5],[11,12,13,14,15],[21,22,23,24,25]]

# %%
from IPython.display import Image # image upload lib
Image(filename='capture.jpg')
